# %%
import datetime

while True:
    now = datetime.datetime.now()
    # get hour and minutes from ts anfis result
    # print("Will be executed at %s:%s" % (now.hour, now.minute))

    if now.hour == 20 and now.minute == 0:
        print ('its time')
    else :
        print ('idle')
# Out:
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# Will be executed at 19:59
# idle
# ...
